# %% [markdown]
# <a href="https://colab.research.google.com/github/dmitrifei/github1140315/blob/main/demo01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## colab寫markdown
# - 正弦波`圖表`範例

# %%
import numpy as np
import matplotlib.pyplot as plt

# 生成 x 軸數據 (0 到 2π 之間的 100 個點)
x = np.linspace(0, 2 * np.pi, 100)

# 計算正弦函數值
y = np.sin(x)

# 繪製圖形
plt.plot(x, y, label='sin(x)', color='b')

# 添加標題與標籤
plt.title('Sine Wave')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.axhline(0, color='black', linewidth=0.5)  # 添加 x 軸
plt.axvline(0, color='black', linewidth=0.5)  # 添加 y 軸
plt.grid(True, linestyle='--', alpha=0.6)  # 添加網格線
plt.legend()  # 顯示圖例

# 顯示圖形
plt.show()

# %% [markdown]
# - 餘弦波圖表

# %%
import numpy as np
import matplotlib.pyplot as plt

# 生成 x 軸數據 (0 到 2π 之間的 100 個點)
x = np.linspace(0, 2 * np.pi, 100)

# 計算餘弦函數值
y = np.cos(x)

# 繪製圖形
plt.plot(x, y, label='cos(x)', color='r')  # 使用紅色線條

# 添加標題與標籤
plt.title('Cosine Wave')
plt.xlabel('x')
plt.ylabel('cos(x)')
plt.axhline(0, color='black', linewidth=0.5)  # 添加 x 軸
plt.axvline(0, color='black', linewidth=0.5)  # 添加 y 軸
plt.grid(True, linestyle='--', alpha=0.6)  # 添加網格線
plt.legend()  # 顯示圖例

# 顯示圖形
plt.show()

# %% [markdown]
# - 同時顯示sin() cos()的正弦和餘弦

# %%
import numpy as np
import matplotlib.pyplot as plt

# 生成 x 軸數據 (0 到 2π 之間的 100 個點)
x = np.linspace(0, 2 * np.pi, 100)

# 計算正弦和餘弦函數值
y_sin = np.sin(x)
y_cos = np.cos(x)

# 繪製圖形
plt.plot(x, y_sin, label='sin(x)', color='b')  # 正弦波，藍色線條
plt.plot(x, y_cos, label='cos(x)', color='r')  # 餘弦波，紅色線條

# 添加標題與標籤
plt.title('Sine and Cosine Waves')
plt.xlabel('x')
plt.ylabel('y')
plt.axhline(0, color='black', linewidth=0.5)  # 添加 x 軸
plt.axvline(0, color='black', linewidth=0.5)  # 添加 y 軸
plt.grid(True, linestyle='--', alpha=0.6)  # 添加網格線
plt.legend()  # 顯示圖例

# 顯示圖形
plt.show()
